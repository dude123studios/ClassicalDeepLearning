# %% [markdown]
# <a href="https://colab.research.google.com/github/dude123studios/AdvancedDeepLearning/blob/main/Image_captioning_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import collections
import random
import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle

# %%
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                          cache_subdir=os.path.abspath('.'),
                                          origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                          extract = True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
  os.remove(annotation_zip)
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                      extract = True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 3s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 325s 0us/step

# %%
with open(annotation_file, 'r') as f:
  annotations = json.load(f)

image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH+'COCO_train2014_'+'%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)
train_image_paths = image_paths[:5000]

# %%
train_captions = []
image_names = []
for image_path in train_image_paths:
  caption_list = image_path_to_captions[image_path]
  train_captions.extend(caption_list)
  image_names.extend([image_path]*len(caption_list))

# %%
print(train_captions[0])
Image.open(image_names[0])

# %% [markdown]
# The output had to be cut out due to githubs image in jupyter notebook support

# %%
def load_image(image_path):
  img = tf.io.read_file(image_path)
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, (299,299))
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  return img, image_path

# %%
image_model = tf.keras.applications.inception_v3.InceptionV3(include_top=False,weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output
image_features_model = tf.keras.models.Model(new_input, hidden_layer)

encode_train = sorted(set(image_names))
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in image_dataset:
  batch_features = image_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())

# %%
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'
train_seqs = tokenizer.texts_to_sequences(train_captions)
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')
max_length = max(len(t) for t in train_seqs)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(image_names, cap_vector):
  img_to_cap_vector[img].append(cap)

img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (20007, 20007, 5003, 5003)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
features_shape = 2048
attention_features_shape = 64

def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.AUTOTUNE)

dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, num_units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(num_units)
    self.W2 = tf.keras.layers.Dense(num_units)
    self.V = tf.keras.layers.Dense(1)
  
  def call(self, query, values):
    
    query = tf.expand_dims(query, axis=1)
    
    distribution = self.V(tf.nn.tanh(self.W1(query)+ self.W2(values)))
    distribution = tf.nn.softmax(distribution)

    context = tf.reduce_sum(
        tf.linalg.matmul(
            tf.linalg.matrix_transpose(distribution),
            values
        ),axis=1
    )
    return context, distribution

# %%
class CNN_Encoder(tf.keras.Model):
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, decoder_dim, vocab_size,**kwargs):
    super(Decoder, self).__init__(**kwargs)
    self.units = decoder_dim
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.rnn = tf.keras.layers.GRU(decoder_dim, return_sequences=True, return_state=True)
    self.W1 = tf.keras.layers.Dense(self.units)
    self.W2 = tf.keras.layers.Dense(vocab_size)
    self.attention = BahdanauAttention(self.units)
  
  def call(self, x, values, state):
    context_vector, attention_weights = self.attention(state, values)
    x = self.embedding(x)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    output, state = self.rnn(x,state)
    x = self.W1(output)
    x = tf.reshape(x, (-1, x.shape[2]))
    x = self.W2(x)
    
    return x, state, attention_weights
    
  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
def loss_fn(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)
  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  return tf.reduce_mean(loss_)

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0
  state = decoder.reset_state(batch_size=target.shape[0])
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']]*target.shape[0],1)
  with tf.GradientTape() as tape:
    features = encoder(img_tensor)
    for i in range(1, target.shape[1]):
      preds, state, _ = decoder(dec_input, features, state)
      loss += loss_fn(target[:,i], preds)
      dec_input = tf.expand_dims(target[:,i], 1)
  total_loss = (loss / int(target.shape[1]))
  trainable_variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, trainable_variables)
  optimizer.apply_gradients(zip(gradients, trainable_variables))
  return loss, total_loss

# %%
EPOCHS = 50
for epoch in range(start_epoch, EPOCHS):
  start_time = time.time()
  total_loss = 0
  for (batch, (img_tensor, target)) in enumerate(dataset):
    batch_loss, t_loss = train_step(img_tensor, target)
    total_loss += t_loss
    if batch % 100 == 0:
      print('Epoch: {}/{}, Batch: {}, loss: {:.4f}'.format(epoch+1,EPOCHS, batch, t_loss / int(target.shape[1])))
  if epoch % 10 == 0:
    encoder.save_weights('encoder_ckpt{}.h5'.format(epoch // 10))
    decoder.save_weights('decoder_ckpt{}.h5'.format(epoch // 10))
  print('Epoch {}, Loss {:.6f}'.format(epoch+1, total_loss/48))
  print ('Time taken for epoch is {} seconds\n'.format(time.time() - start_time))
# Out:
# Epoch: 1/50, Batch: 0, loss: 0.0267
# Epoch: 1/50, Batch: 100, loss: 0.0244
# Epoch: 1/50, Batch: 200, loss: 0.0250
# Epoch: 1/50, Batch: 300, loss: 0.0242
# Epoch 1, Loss 7.877653
# Time taken for epoch is 51.739614963531494 seconds
#
# Epoch: 2/50, Batch: 0, loss: 0.0262
# Epoch: 2/50, Batch: 100, loss: 0.0254
# Epoch: 2/50, Batch: 200, loss: 0.0267
# Epoch: 2/50, Batch: 300, loss: 0.0226
# Epoch 2, Loss 7.772827
# Time taken for epoch is 51.69720125198364 seconds
#
# Epoch: 3/50, Batch: 0, loss: 0.0259
# Epoch: 3/50, Batch: 100, loss: 0.0246
# Epoch: 3/50, Batch: 200, loss: 0.0236
# Epoch: 3/50, Batch: 300, loss: 0.0237
# Epoch 3, Loss 7.477122
# Time taken for epoch is 51.70173978805542 seconds
#
# Epoch: 4/50, Batch: 0, loss: 0.0233
# Epoch: 4/50, Batch: 100, loss: 0.0248
# Epoch: 4/50, Batch: 200, loss: 0.0234
# Epoch: 4/50, Batch: 300, loss: 0.0238
# Epoch 4, Loss 7.212861
# Time taken for epoch is 51.62812161445618 seconds
#
# Epoch: 5/50, Batch: 0, loss: 0.0235
# Epoch: 5/50, Batch: 100, loss: 0.0221
# Epoch: 5/50, Batch: 200, loss: 0.0222
# Epoch: 5/50, Batch: 300, loss: 0.0235
# Epoch 5, Loss 7.050589
# Time taken for epoch is 51.75724744796753 seconds
#
# Epoch: 6/50, Batch: 0, loss: 0.0234
# Epoch: 6/50, Batch: 100, loss: 0.0211
# Epoch: 6/50, Batch: 200, loss: 0.0223
# Epoch: 6/50, Batch: 300, loss: 0.0212
# Epoch 6, Loss 6.843173
# Time taken for epoch is 51.261472940444946 seconds
#
# Epoch: 7/50, Batch: 0, loss: 0.0224
# Epoch: 7/50, Batch: 100, loss: 0.0219
# Epoch: 7/50, Batch: 200, loss: 0.0206
# Epoch: 7/50, Batch: 300, loss: 0.0207
# Epoch 7, Loss 6.628206
# Time taken for epoch is 51.479243516922 seconds
#
# Epoch: 8/50, Batch: 0, loss: 0.0205
# Epoch: 8/50, Batch: 100, loss: 0.0214
# Epoch: 8/50, Batch: 200, loss: 0.0204
# Epoch: 8/50, Batch: 300, loss: 0.0210
# Epoch 8, Loss 6.502429
# Time taken for epoch is 51.61349940299988 seconds
#
# Epoch: 9/50, Batch: 0, loss: 0.0192
# Epoch: 9/50, Batch: 100, loss: 0.0199
# Epoch: 9/50, Batch: 200, loss: 0.0203
# Epoch: 9/50, Batch: 300, loss: 0.0185
# Epoch 9, Loss 6.403843
# Time taken for epoch is 51.4746527671814 seconds
#
# Epoch: 10/50, Batch: 0, loss: 0.0210
# Epoch: 10/50, Batch: 100, loss: 0.0202
# Epoch: 10/50, Batch: 200, loss: 0.0207
# Epoch: 10/50, Batch: 300, loss: 0.0191
# Epoch 10, Loss 6.323666
# Time taken for epoch is 51.33449959754944 seconds
#
# Epoch: 11/50, Batch: 0, loss: 0.0198
# Epoch: 11/50, Batch: 100, loss: 0.0209
# Epoch: 11/50, Batch: 200, loss: 0.0202
# Epoch: 11/50, Batch: 300, loss: 0.0189
# Epoch 11, Loss 6.223297
# Time taken for epoch is 51.67075777053833 seconds
#
# Epoch: 12/50, Batch: 0, loss: 0.0194
# Epoch: 12/50, Batch: 100, loss: 0.0195
# Epoch: 12/50, Batch: 200, loss: 0.0205
# Epoch: 12/50, Batch: 300, loss: 0.0186
# Epoch 12, Loss 6.138987
# Time taken for epoch is 51.39245676994324 seconds
#
# Epoch: 13/50, Batch: 0, loss: 0.0198
# Epoch: 13/50, Batch: 100, loss: 0.0201
# Epoch: 13/50, Batch: 200, loss: 0.0186
# Epoch: 13/50, Batch: 300, loss: 0.0181
# Epoch 13, Loss 6.053625
# Time taken for epoch is 51.54291343688965 seconds
#
# Epoch: 14/50, Batch: 0, loss: 0.0179
# Epoch: 14/50, Batch: 100, loss: 0.0188
# Epoch: 14/50, Batch: 200, loss: 0.0189
# Epoch: 14/50, Batch: 300, loss: 0.0185
# Epoch 14, Loss 5.982179
# Time taken for epoch is 51.31830024719238 seconds
#
# Epoch: 15/50, Batch: 0, loss: 0.0197
# Epoch: 15/50, Batch: 100, loss: 0.0184
# Epoch: 15/50, Batch: 200, loss: 0.0188
# Epoch: 15/50, Batch: 300, loss: 0.0206
# Epoch 15, Loss 5.917384
# Time taken for epoch is 51.54852271080017 seconds
#
# Epoch: 16/50, Batch: 0, loss: 0.0197
# Epoch: 16/50, Batch: 100, loss: 0.0187
# Epoch: 16/50, Batch: 200, loss: 0.0190
# Epoch: 16/50, Batch: 300, loss: 0.0169
# Epoch 16, Loss 5.758241
# Time taken for epoch is 51.54548931121826 seconds
#
# Epoch: 17/50, Batch: 0, loss: 0.0190
# Epoch: 17/50, Batch: 100, loss: 0.0198
# Epoch: 17/50, Batch: 200, loss: 0.0185
# Epoch: 17/50, Batch: 300, loss: 0.0167
# Epoch 17, Loss 5.645342
# Time taken for epoch is 51.51354622840881 seconds
#
# Epoch: 18/50, Batch: 0, loss: 0.0171
# Epoch: 18/50, Batch: 100, loss: 0.0170
# Epoch: 18/50, Batch: 200, loss: 0.0177
# Epoch: 18/50, Batch: 300, loss: 0.0160
# Epoch 18, Loss 5.581341
# Time taken for epoch is 51.48354649543762 seconds
#
# Epoch: 19/50, Batch: 0, loss: 0.0181
# Epoch: 19/50, Batch: 100, loss: 0.0195
# Epoch: 19/50, Batch: 200, loss: 0.0164
# Epoch: 19/50, Batch: 300, loss: 0.0188
# Epoch 19, Loss 5.531555
# Time taken for epoch is 51.72471213340759 seconds
#
# Epoch: 20/50, Batch: 0, loss: 0.0179
# Epoch: 20/50, Batch: 100, loss: 0.0172
# Epoch: 20/50, Batch: 200, loss: 0.0171
# Epoch: 20/50, Batch: 300, loss: 0.0182
# Epoch 20, Loss 5.491992
# Time taken for epoch is 51.52708196640015 seconds
#
# Epoch: 21/50, Batch: 0, loss: 0.0164
# Epoch: 21/50, Batch: 100, loss: 0.0166
# Epoch: 21/50, Batch: 200, loss: 0.0183
# Epoch: 21/50, Batch: 300, loss: 0.0158
# Epoch 21, Loss 5.431572
# Time taken for epoch is 51.66433334350586 seconds
#
# Epoch: 22/50, Batch: 0, loss: 0.0171
# Epoch: 22/50, Batch: 100, loss: 0.0178
# Epoch: 22/50, Batch: 200, loss: 0.0186
# Epoch: 22/50, Batch: 300, loss: 0.0164
# Epoch 22, Loss 5.412214
# Time taken for epoch is 51.852015018463135 seconds
#
# Epoch: 23/50, Batch: 0, loss: 0.0183
# Epoch: 23/50, Batch: 100, loss: 0.0168
# Epoch: 23/50, Batch: 200, loss: 0.0183
# Epoch: 23/50, Batch: 300, loss: 0.0161
# Epoch 23, Loss 5.359625
# Time taken for epoch is 51.63801980018616 seconds
#
# Epoch: 24/50, Batch: 0, loss: 0.0163
# Epoch: 24/50, Batch: 100, loss: 0.0163
# Epoch: 24/50, Batch: 200, loss: 0.0165
# Epoch: 24/50, Batch: 300, loss: 0.0159
# Epoch 24, Loss 5.345484
# Time taken for epoch is 51.62036466598511 seconds
#
# Epoch: 25/50, Batch: 0, loss: 0.0172
# Epoch: 25/50, Batch: 100, loss: 0.0165
# Epoch: 25/50, Batch: 200, loss: 0.0173
# Epoch: 25/50, Batch: 300, loss: 0.0155
# Epoch 25, Loss 5.297658
# Time taken for epoch is 51.638816356658936 seconds
#
# Epoch: 26/50, Batch: 0, loss: 0.0168
# Epoch: 26/50, Batch: 100, loss: 0.0154
# Epoch: 26/50, Batch: 200, loss: 0.0166
# Epoch: 26/50, Batch: 300, loss: 0.0168
# Epoch 26, Loss 5.281929
# Time taken for epoch is 51.721999168395996 seconds
#
# Epoch: 27/50, Batch: 0, loss: 0.0178
# Epoch: 27/50, Batch: 100, loss: 0.0183
# Epoch: 27/50, Batch: 200, loss: 0.0177
# Epoch: 27/50, Batch: 300, loss: 0.0165
# Epoch 27, Loss 5.268140
# Time taken for epoch is 51.538954973220825 seconds
#
# Epoch: 28/50, Batch: 0, loss: 0.0171
# Epoch: 28/50, Batch: 100, loss: 0.0167
# Epoch: 28/50, Batch: 200, loss: 0.0169
# Epoch: 28/50, Batch: 300, loss: 0.0160
# Epoch 28, Loss 5.240957
# Time taken for epoch is 51.71806621551514 seconds
#
# Epoch: 29/50, Batch: 0, loss: 0.0167
# Epoch: 29/50, Batch: 100, loss: 0.0168
# Epoch: 29/50, Batch: 200, loss: 0.0163
# Epoch: 29/50, Batch: 300, loss: 0.0175
# Epoch 29, Loss 5.215420
# Time taken for epoch is 51.572096824645996 seconds
#
# Epoch: 30/50, Batch: 0, loss: 0.0171
# Epoch: 30/50, Batch: 100, loss: 0.0169
# Epoch: 30/50, Batch: 200, loss: 0.0174
# Epoch: 30/50, Batch: 300, loss: 0.0168
# Epoch 30, Loss 5.188876
# Time taken for epoch is 51.66999816894531 seconds
#
# Epoch: 31/50, Batch: 0, loss: 0.0169
# Epoch: 31/50, Batch: 100, loss: 0.0167
# Epoch: 31/50, Batch: 200, loss: 0.0158
# Epoch: 31/50, Batch: 300, loss: 0.0187
# Epoch 31, Loss 5.166759
# Time taken for epoch is 52.106478691101074 seconds
#
# Epoch: 32/50, Batch: 0, loss: 0.0163
# Epoch: 32/50, Batch: 100, loss: 0.0170
# Epoch: 32/50, Batch: 200, loss: 0.0166
# Epoch: 32/50, Batch: 300, loss: 0.0158
# Epoch 32, Loss 5.144271
# Time taken for epoch is 51.723418951034546 seconds
#
# Epoch: 33/50, Batch: 0, loss: 0.0174
# Epoch: 33/50, Batch: 100, loss: 0.0161
# Epoch: 33/50, Batch: 200, loss: 0.0167
# Epoch: 33/50, Batch: 300, loss: 0.0151
# Epoch 33, Loss 5.127218
# Time taken for epoch is 51.63380527496338 seconds
#
# Epoch: 34/50, Batch: 0, loss: 0.0163
# Epoch: 34/50, Batch: 100, loss: 0.0173
# Epoch: 34/50, Batch: 200, loss: 0.0175
# Epoch: 34/50, Batch: 300, loss: 0.0154
# Epoch 34, Loss 5.114050
# Time taken for epoch is 51.60098624229431 seconds
#
# Epoch: 35/50, Batch: 0, loss: 0.0157
# Epoch: 35/50, Batch: 100, loss: 0.0153
# Epoch: 35/50, Batch: 200, loss: 0.0167
# Epoch: 35/50, Batch: 300, loss: 0.0163
# Epoch 35, Loss 5.085528
# Time taken for epoch is 51.955039262771606 seconds
#
# Epoch: 36/50, Batch: 0, loss: 0.0166
# Epoch: 36/50, Batch: 100, loss: 0.0155
# Epoch: 36/50, Batch: 200, loss: 0.0183
# Epoch: 36/50, Batch: 300, loss: 0.0165
# Epoch 36, Loss 5.068513
# Time taken for epoch is 51.76982235908508 seconds
#
# Epoch: 37/50, Batch: 0, loss: 0.0167
# Epoch: 37/50, Batch: 100, loss: 0.0155
# Epoch: 37/50, Batch: 200, loss: 0.0160
# Epoch: 37/50, Batch: 300, loss: 0.0168
# Epoch 37, Loss 5.044139
# Time taken for epoch is 51.98690152168274 seconds
#
# Epoch: 38/50, Batch: 0, loss: 0.0171
# Epoch: 38/50, Batch: 100, loss: 0.0161
# Epoch: 38/50, Batch: 200, loss: 0.0164
# Epoch: 38/50, Batch: 300, loss: 0.0152
# Epoch 38, Loss 5.039395
# Time taken for epoch is 51.675487756729126 seconds
#
# Epoch: 39/50, Batch: 0, loss: 0.0151
# Epoch: 39/50, Batch: 100, loss: 0.0160
# Epoch: 39/50, Batch: 200, loss: 0.0165
# Epoch: 39/50, Batch: 300, loss: 0.0161
# Epoch 39, Loss 5.012917
# Time taken for epoch is 51.56841325759888 seconds
#
# Epoch: 40/50, Batch: 0, loss: 0.0169
# Epoch: 40/50, Batch: 100, loss: 0.0160
# Epoch: 40/50, Batch: 200, loss: 0.0153
# Epoch: 40/50, Batch: 300, loss: 0.0155
# Epoch 40, Loss 5.011711
# Time taken for epoch is 51.46952486038208 seconds
#
# Epoch: 41/50, Batch: 0, loss: 0.0157
# Epoch: 41/50, Batch: 100, loss: 0.0162
# Epoch: 41/50, Batch: 200, loss: 0.0165
# Epoch: 41/50, Batch: 300, loss: 0.0150
# Epoch 41, Loss 4.997680
# Time taken for epoch is 51.68637704849243 seconds
#
# Epoch: 42/50, Batch: 0, loss: 0.0157
# Epoch: 42/50, Batch: 100, loss: 0.0152
# Epoch: 42/50, Batch: 200, loss: 0.0161
# Epoch: 42/50, Batch: 300, loss: 0.0165
# Epoch 42, Loss 4.973401
# Time taken for epoch is 51.214266538619995 seconds
#
# Epoch: 43/50, Batch: 0, loss: 0.0161
# Epoch: 43/50, Batch: 100, loss: 0.0148
# Epoch: 43/50, Batch: 200, loss: 0.0160
# Epoch: 43/50, Batch: 300, loss: 0.0144
# Epoch 43, Loss 4.969502
# Time taken for epoch is 51.18881130218506 seconds
#
# Epoch: 44/50, Batch: 0, loss: 0.0168
# Epoch: 44/50, Batch: 100, loss: 0.0158
# Epoch: 44/50, Batch: 200, loss: 0.0160
# Epoch: 44/50, Batch: 300, loss: 0.0161
# Epoch 44, Loss 4.946668
# Time taken for epoch is 51.333428144454956 seconds
#
# Epoch: 45/50, Batch: 0, loss: 0.0155
# Epoch: 45/50, Batch: 100, loss: 0.0163
# Epoch: 45/50, Batch: 200, loss: 0.0178
# Epoch: 45/50, Batch: 300, loss: 0.0151
# Epoch 45, Loss 4.940307
# Time taken for epoch is 51.142582654953 seconds
#
# Epoch: 46/50, Batch: 0, loss: 0.0161
# Epoch: 46/50, Batch: 100, loss: 0.0152
# Epoch: 46/50, Batch: 200, loss: 0.0161
# Epoch: 46/50, Batch: 300, loss: 0.0149
# Epoch 46, Loss 4.926296
# Time taken for epoch is 51.35186147689819 seconds
#
# Epoch: 47/50, Batch: 0, loss: 0.0165
# Epoch: 47/50, Batch: 100, loss: 0.0168
# Epoch: 47/50, Batch: 200, loss: 0.0152
# Epoch: 47/50, Batch: 300, loss: 0.0170
# Epoch 47, Loss 4.901730
# Time taken for epoch is 51.675276041030884 seconds
#
# Epoch: 48/50, Batch: 0, loss: 0.0159
# Epoch: 48/50, Batch: 100, loss: 0.0144
# Epoch: 48/50, Batch: 200, loss: 0.0152
# Epoch: 48/50, Batch: 300, loss: 0.0156
# Epoch 48, Loss 4.899986
# Time taken for epoch is 51.27980017662048 seconds
#
# Epoch: 49/50, Batch: 0, loss: 0.0174
# Epoch: 49/50, Batch: 100, loss: 0.0154
# Epoch: 49/50, Batch: 200, loss: 0.0164
# Epoch: 49/50, Batch: 300, loss: 0.0158
# Epoch 49, Loss 4.879889
# Time taken for epoch is 51.1631133556366 seconds
#
# Epoch: 50/50, Batch: 0, loss: 0.0161
# Epoch: 50/50, Batch: 100, loss: 0.0154
# Epoch: 50/50, Batch: 200, loss: 0.0164
# Epoch: 50/50, Batch: 300, loss: 0.0138
# Epoch 50, Loss 4.864629
# Time taken for epoch is 51.19960141181946 seconds
